# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn import datasets
# %matplotlib inline#gives uniform dimensions for the figures
# Out:
# UsageError: unrecognized arguments: uniform dimensions for the figures

# %%
sns.regplot(x="SepalLengthCm", y="PetalLengthCm", data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
dataset = pd.read_csv("Iris.csv")

# %%
df = pd.DataFrame(dataset)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.regplot(x="SepalLengthCm",y="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.barplot(x="SepalLengthCm",y="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.catplot(x="SepalLengthCm",y="PetalLengthCm",data=df)

# %%
sns.violinplot(x="SepalLengthCm",y="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
aryan = sns.load_dataset("tips")
aryan.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x=aryan["total_bill"],y=aryan["sex"])#,data=aryan)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.histplot(x=aryan["total_bill"],kde=True)#,y=aryan["sex"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.pairplot(aryan,hue="sex")#,hue_order="total_bill"

# %%
d4 = np.random.randint(low = 1,
                         high = 100,
                         size = (10, 10))

# %%
sns.heatmap[d4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-640632112627> in <cell line: 1>()
# ----> 1 sns.heatmap[d4]
#
# TypeError: 'function' object is not subscriptable

# %%
sns.lineplot(x=aryan["total_bill"],y=aryan["sex"])
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>
