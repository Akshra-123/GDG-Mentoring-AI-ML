# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("200 salary.csv")

# %%
df = pd.DataFrame(data)
df.shape
df
# Out:
#      YearsExperience    Salary
# 0                1.1   39343.0
# 1                1.3   46205.0
# 2                1.5   37731.0
# 3                2.0   43525.0
# 4                2.2   39891.0
# ..               ...       ...
# 175              9.0  105582.0
# 176              9.5  116969.0
# 177              9.6  112635.0
# 178             10.3  122391.0
# 179             10.5  121872.0
#
# [180 rows x 2 columns]

# %%
x=df[["YearsExperience"]]#data
y=df[["Salary"]]#target... mostly dependent variable


# if we dont write  x as x=df[age] it will treat it as a 1D data
# if we write x as x=df[[age]] it will treat it as 2D data

# %%
df["Salary"].shape #Tried to get the shapes of both height and age simultaniously
# Out:
# (180,)

# %%
df["YearsExperience"].name
# Out:
# 'YearsExperience'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_test.shape
# Out:
# (36, 1)

# %%
x_train.shape #here we are getting 2 columns the 1st one is for marking the numbers or serial numbers
# Out:
# (144, 1)

# %%
y_test
# Out:
#        Salary
# 116  116969.0
# 112  101302.0
# 99    57189.0
# 161   55794.0
# 35    56642.0
# 54   109431.0
# 69    57189.0
# 19    93940.0
# 110   91738.0
# 127   54445.0
# 106   66029.0
# 107   83088.0
# 11    55794.0
# 108   81363.0
# 4     39891.0
# 124   39891.0
# 14    61111.0
# 120   39343.0
# 29   121872.0
# 123   43525.0
# 158   64445.0
# 42    56957.0
# 51    98273.0
# 174  109431.0
# 53   113812.0
# 40    63218.0
# 48    81363.0
# 66    60150.0
# 159   57189.0
# 31    46205.0
# 16    66029.0
# 94    39891.0
# 56   116969.0
# 95    56642.0
# 5     56642.0
# 167   83088.0

# %%
y_train.shape
# Out:
# (144, 1)

# %%
print("x shape:", x.shape)  # Should be (19, 1)
print("y shape:", y.shape)  # Should be (19,)
# Out:
# x shape: (180, 1)
# y shape: (180, 1)

# %%
model=LinearRegression() #import's the linear regression model

# %%
model.fit(x_train,y_train) #fits the data into the model with the xtrain and ytrain values
# Out:
# LinearRegression()

# %%
print(model.intercept_)  # it is the c in the formula for slope of a graph "y=mx+c"
# Out:
# [26128.0317423]

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [[115262.86139312]
#  [100250.67955719]
#  [ 60843.70223788]
#  [ 63658.48633212]
#  [ 53337.61131992]
#  [107756.77047516]
#  [ 60843.70223788]
#  [ 82423.71362703]
#  [ 89929.80454499]
#  [ 56152.39541415]
#  [ 73979.36134432]
#  [ 75855.88407381]
#  [ 63658.48633212]
#  [ 81485.45226228]
#  [ 46769.7817667 ]
#  [ 46769.7817667 ]
#  [ 68349.79315585]
#  [ 36448.9067545 ]
#  [124645.47504057]
#  [ 44893.25903721]
#  [ 56152.39541415]
#  [ 63658.48633212]
#  [ 92744.58863923]
#  [107756.77047516]
#  [103065.46365143]
#  [ 62720.22496737]
#  [ 81485.45226228]
#  [ 54275.87268466]
#  [ 60843.70223788]
#  [ 38325.42948399]
#  [ 73979.36134432]
#  [ 46769.7817667 ]
#  [115262.86139312]
#  [ 53337.61131992]
#  [ 53337.61131992]
#  [ 75855.88407381]]

# %%
rdf=pd.DataFrame(y_pred)
rdf
# Out:
#                 0
# 0   115262.861393
# 1   100250.679557
# 2    60843.702238
# 3    63658.486332
# 4    53337.611320
# 5   107756.770475
# 6    60843.702238
# 7    82423.713627
# 8    89929.804545
# 9    56152.395414
# 10   73979.361344
# 11   75855.884074
# 12   63658.486332
# 13   81485.452262
# 14   46769.781767
# 15   46769.781767
# 16   68349.793156
# 17   36448.906754
# 18  124645.475041
# 19   44893.259037
# 20   56152.395414
# 21   63658.486332
# 22   92744.588639
# 23  107756.770475
# 24  103065.463651
# 25   62720.224967
# 26   81485.452262
# 27   54275.872685
# 28   60843.702238
# 29   38325.429484
# 30   73979.361344
# 31   46769.781767
# 32  115262.861393
# 33   53337.611320
# 34   53337.611320
# 35   75855.884074

# %%
test_data = 19.0
model.predict([[test_data]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[204397.69104394]])

# %%
from sklearn.metrics import mean_absolute_error

y_baseline = np.mean(y_train)
baseline_error = mean_absolute_error(y_test, [y_baseline] * len(y_test))

model_error = mean_absolute_error(y_test, y_pred)

accuracy = 1 - (model_error / baseline_error)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 79.31%

# %%
max_experience = X['YearsExperience'].max()
new_experience = np.linspace(max_experience + 0.1, max_experience + 2, 20).reshape(-1, 1)
new_salaries = model.predict(new_experience)

new_data=pd.DataFrame({
    "YearsExperience":new_experience.flatten(),
    "PredictedSalary":new_salaries
})
print(new_data)
# Out:
#     YearsExperience  PredictedSalary
# 0              10.6    125583.736405
# 1              10.7    126521.997770
# 2              10.8    127460.259135
# 3              10.9    128398.520500
# 4              11.0    129336.781864
# 5              11.1    130275.043229
# 6              11.2    131213.304594
# 7              11.3    132151.565959
# 8              11.4    133089.827323
# 9              11.5    134028.088688
# 10             11.6    134966.350053
# 11             11.7    135904.611418
# 12             11.8    136842.872782
# 13             11.9    137781.134147
# 14             12.0    138719.395512
# 15             12.1    139657.656877
# 16             12.2    140595.918241
# 17             12.3    141534.179606
# 18             12.4    142472.440971
# 19             12.5    143410.702335
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
# ...

# %%
#used a premade model to check how can i have the output in the df form which will include both yearsexperience and salary



import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load the dataset


# Define independent (X) and dependent (y) variables
X = data[['YearsExperience']]
y = data['Salary']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Generate 20 more years of experience values beyond the current dataset
max_experience = X['YearsExperience'].max()
new_experience = np.linspace(max_experience + 0.1, max_experience + 2, 20).reshape(-1, 1)

# Predict salaries for these new experience values
new_salaries = model.predict(new_experience)

# Combine the new experience and predicted salaries into a DataFrame
new_data = pd.DataFrame({
    'YearsExperience': new_experience.flatten(),
    'PredictedSalary': new_salaries
})

print(new_data)
# Out:
#     YearsExperience  PredictedSalary
# 0              10.6    125583.736405
# 1              10.7    126521.997770
# 2              10.8    127460.259135
# 3              10.9    128398.520500
# 4              11.0    129336.781864
# 5              11.1    130275.043229
# 6              11.2    131213.304594
# 7              11.3    132151.565959
# 8              11.4    133089.827323
# 9              11.5    134028.088688
# 10             11.6    134966.350053
# 11             11.7    135904.611418
# 12             11.8    136842.872782
# 13             11.9    137781.134147
# 14             12.0    138719.395512
# 15             12.1    139657.656877
# 16             12.2    140595.918241
# 17             12.3    141534.179606
# 18             12.4    142472.440971
# 19             12.5    143410.702335
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
# ...
