# %%
import pandas as pd
import random
import numpy as np

# %%
rand = ["1","2","3"]
d = {"a":1,"b":2,"c":3}
pd.Series(data = rand  ,index=d)
# Out:
# a    1
# b    2
# c    3
# dtype: object

# %%
names = ["akshat","priyansh","aryan","himesh"]
x = {"best":1,"nalla":2,"ameer":3,"prodigy":4}
pd.Series(data=names,index=x)
pd.Series(names,x)
# Out:
# best         akshat
# nalla      priyansh
# ameer         aryan
# prodigy      himesh
# dtype: object

# %%
pd.Series(x)
# Out:
# best       1
# nalla      2
# ameer      3
# prodigy    4
# dtype: int64

# %%
y = pd.Series([1,2,3],["a","b","c"])
y["a"]#gives the index of the data that has been been given
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-9796e064e7eb> in <cell line: 3>()
#       1 #y = pd.Series([1,2,3],["a","b","c"])
#       2 y = pd.DataFrame([1,2,3],["a","b","c"])
# ----> 3 y["a"]#gives the index of the data that has been assigned
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
# ...

# %%
from numpy.random import randn

# %%
 df = pd.DataFrame(randn(6,9),["1","2","3","4","5","6"],["a","b","c","d","e","f","g","h","i"])#here we are making a dataframe with rows and columns of 6 and 9 respectively(always put rows first then columns)and using randn to fill it up with numbers
 df
# Out:
#           a         b         c         d         e         f         g  \
# 1  2.352411 -1.122531  0.262570  0.143539  0.584887 -0.685882  1.221780
# 2 -0.393898  0.340228 -0.555750  0.362286 -0.521153 -0.392256  0.613446
# 3 -0.337536  1.462863 -0.339565 -1.562801 -0.950191 -1.936793 -0.025853
# 4  0.544938  0.509467 -0.140185  1.091287 -0.689263 -0.949095 -1.285557
# 5 -0.128126  0.914684 -1.505970  0.914465 -0.016629  0.220843 -1.239599
# 6  0.007366  0.142211 -0.968920  1.004453 -0.020952  0.055683  0.034274
#
#           h         i
# 1  1.152164 -1.338010
# 2 -1.089889  1.525986
# 3 -1.589697  1.912352
# 4  0.220496 -1.585763
# 5 -0.872138  1.167398
# 6 -0.117435 -0.833653

# %%
df.iloc[3,8]
# Out:
# -1.5857626302256178

# %%
#df["a"],["b"],["c"]
# Out:
# (1    2.352411
#  2   -0.393898
#  3   -0.337536
#  4    0.544938
#  5   -0.128126
#  6    0.007366
#  Name: a, dtype: float64,
#  ['b'],
#  ['c'])

# %%
df["a"]
# Out:
# 1    2.352411
# 2   -0.393898
# 3   -0.337536
# 4    0.544938
# 5   -0.128126
# 6    0.007366
# Name: a, dtype: float64

# %%
new_df=df[["f","g"]]
new_df
# Out:
#           f         g
# 1 -0.685882  1.221780
# 2 -0.392256  0.613446
# 3 -1.936793 -0.025853
# 4 -0.949095 -1.285557
# 5  0.220843 -1.239599
# 6  0.055683  0.034274

# %%
#new_df=pd.DataFrame(randn(2,2),["7","8"],["j","k"])
#df["new_df"]=new_df

# %%
df["new_df"]=df["f"] +df["i"]
df
# Out:
#           a         b         c         d         e         f         g  \
# 1  2.352411 -1.122531  0.262570  0.143539  0.584887 -0.685882  1.221780
# 2 -0.393898  0.340228 -0.555750  0.362286 -0.521153 -0.392256  0.613446
# 3 -0.337536  1.462863 -0.339565 -1.562801 -0.950191 -1.936793 -0.025853
# 4  0.544938  0.509467 -0.140185  1.091287 -0.689263 -0.949095 -1.285557
# 5 -0.128126  0.914684 -1.505970  0.914465 -0.016629  0.220843 -1.239599
# 6  0.007366  0.142211 -0.968920  1.004453 -0.020952  0.055683  0.034274
#
#           h         i    new_df
# 1  1.152164 -1.338010 -2.023892
# 2 -1.089889  1.525986  1.133729
# 3 -1.589697  1.912352 -0.024441
# 4  0.220496 -1.585763 -2.534858
# 5 -0.872138  1.167398  1.388241
# 6 -0.117435 -0.833653 -0.777970

# %%
df.drop("new_df",axis=1,inplace=True)#df.drop deletes the existing row/columns jsut make sure to specify the axis
df
# Out:
#           a         b         c         d         e         f         g  \
# 1  2.352411 -1.122531  0.262570  0.143539  0.584887 -0.685882  1.221780
# 2 -0.393898  0.340228 -0.555750  0.362286 -0.521153 -0.392256  0.613446
# 3 -0.337536  1.462863 -0.339565 -1.562801 -0.950191 -1.936793 -0.025853
# 4  0.544938  0.509467 -0.140185  1.091287 -0.689263 -0.949095 -1.285557
# 5 -0.128126  0.914684 -1.505970  0.914465 -0.016629  0.220843 -1.239599
# 6  0.007366  0.142211 -0.968920  1.004453 -0.020952  0.055683  0.034274
#
#           h         i
# 1  1.152164 -1.338010
# 2 -1.089889  1.525986
# 3 -1.589697  1.912352
# 4  0.220496 -1.585763
# 5 -0.872138  1.167398
# 6 -0.117435 -0.833653

# %%
df.loc["1","a"]
# Out:
# 2.3524114213377163
