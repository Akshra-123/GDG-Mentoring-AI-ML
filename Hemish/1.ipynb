# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = ["Python", "Java", "C++"]
x_native = ["Hindi", "English", "punjabi"]
p = np.linspace(1, 3*len(x), 3)
y1 = [1,2,3]
y2 = [5, 6, 7]

width = 1

p1 = p-(width/2)
p2 = p+(width/2)

plt.bar(p1, y1, width=width, color="black", align="center")
plt.bar(p2, y2, width=width, align="center")

plt.show()
