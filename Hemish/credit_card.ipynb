# %%
# !pip install imblearn --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# DEPRECATION: Loading egg at /usr/lib/python3.12/site-packages/airdrop_ng-1.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/lib/python3.12/site-packages/airgraph_ng-1.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: imblearn in /home/hemish/.local/lib/python3.12/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/hemish/.local/lib/python3.12/site-packages (from imblearn) (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (2.1.3)
# Requirement already satisfied: scipy>=1.5.0 in /usr/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (3.4.0)

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
# replace creditcard.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
credit_card = pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card['Class'].unique()
# Out:
# array([0, 1])

# %%
smote = SMOTE(random_state=27)

# %%
x = credit_card.drop(columns=['Class'])

# %%
x
# Out:
#             Time         V1         V2  ...       V27       V28  Amount
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053  149.62
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    2.69
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752  378.66
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458  123.50
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153   69.99
# ...          ...        ...        ...  ...       ...       ...     ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    0.77
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527   24.79
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561   67.88
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533   10.00
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649  217.00
#
# [284807 rows x 30 columns]

# %%
y = credit_card['Class']

# %%
x_resample, y_resample = smote.fit_resample(x, y)

# %%
x_resample
# Out:
#                  Time         V1         V2  ...       V27       V28      Amount
# 0            0.000000  -1.359807  -0.072781  ...  0.133558 -0.021053  149.620000
# 1            0.000000   1.191857   0.266151  ... -0.008983  0.014724    2.690000
# 2            1.000000  -1.358354  -1.340163  ... -0.055353 -0.059752  378.660000
# 3            1.000000  -0.966272  -0.185226  ...  0.062723  0.061458  123.500000
# 4            2.000000  -1.158233   0.877737  ...  0.219422  0.215153   69.990000
# ...               ...        ...        ...  ...       ...       ...         ...
# 568625   28675.066412 -28.863619  16.016857  ...  1.290162  0.376304   99.990000
# 568626  155629.259708  -1.248087   4.089932  ...  0.631673  0.319817    1.576906
# 568627   93860.000000 -10.850282   6.727466  ... -1.464630 -0.411682   78.000000
# 568628  160692.254645  -0.468407   4.465408  ...  0.740347  0.307942   15.744650
# 568629   17228.036446  -0.398196   1.101727  ... -0.095649  0.040028    3.923607
#
# [568630 rows x 30 columns]

# %%
y_resample.value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64
