# %%
# Pandas

import pandas as pd

# %%
import numpy as np

# %%
rand = [1,2,3]
d = {'a':1, 'b':2, 'c':3}
pd.Series(data=rand, index=d)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(rand,d)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
label = ['a','b','c']

# %%
x = pd.Series(data = label)

# %%
x
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
nigga = pd.Series([1,2,3],['aryan','himesh','akshit'])

# %%
nigga
# Out:
# aryan     1
# himesh    2
# akshit    3
# dtype: int64

# %%
nigga['aryan']
# Out:
# 1

# %%
x + nigga
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# akshit    NaN
# aryan     NaN
# himesh    NaN
# dtype: object

# %%
#dataframes

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A',"b",'c','d','e'],['f','g','h','i'])

# %%
df
# Out:
#           f         g         h         i
# A  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.iloc[3,2]
# Out:
# -0.9332372163009188

# %%
df["g"]
# Out:
# A    0.628133
# b   -0.319318
# c    0.740122
# d   -0.758872
# e    1.978757
# Name: g, dtype: float64

# %%
new_df = df[['f','g']]

# %%
new_df
# Out:
#           f         g
# A  2.706850  0.628133
# b  0.651118 -0.319318
# c -2.018168  0.740122
# d  0.188695 -0.758872
# e  0.190794  1.978757

# %%
df['new_df'] = df["h"] + df["i"]

# %%
df
# Out:
#           f         g         h         i    new_df
# A  2.706850  0.628133  0.907969  0.503826  1.411795
# b  0.651118 -0.319318 -0.848077  0.605965 -0.242112
# c -2.018168  0.740122  0.528813 -0.589001 -0.060187
# d  0.188695 -0.758872 -0.933237  0.955057  0.021819
# e  0.190794  1.978757  2.605967  0.683509  3.289476

# %%
df.drop('new_df',axis=1,inplace=True)

# %%
df
# Out:
#           f         g         h         i
# A  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['c','g']
# Out:
# 0.7401220570561068

# %%
df.loc[['A','b'],['f','g']]
# Out:
#           f         g
# A  2.706850  0.628133
# b  0.651118 -0.319318

# %%
df.describe()
# Out:
#               f         g         h         i
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.343858  0.453764  0.452287  0.431871
# std    1.681131  1.061385  1.454516  0.594708
# min   -2.018168 -0.758872 -0.933237 -0.589001
# 25%    0.188695 -0.319318 -0.848077  0.503826
# 50%    0.190794  0.628133  0.528813  0.605965
# 75%    0.651118  0.740122  0.907969  0.683509
# max    2.706850  1.978757  2.605967  0.955057

# %%
EDA -->> Exploratory Data Analysis
# Out:
#   File "<ipython-input-28-a237d27ac2bd>", line 1
#     EDA -->> Exploratory Data Analysis
#          ^
# SyntaxError: invalid syntax

# %%
gigga = pd.DataFrame(np.random.randn(69,5), index=np.arange(69))

# %%
gigga
# Out:
#            0         1         2         3         4
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 1   0.390528  0.166905  0.184502  0.807706  0.072960
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984
# ..       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314142  2.601240 -0.612552 -1.714963
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794
#
# [69 rows x 5 columns]

# %%
gigga.head(8)
# Out:
#           0         1         2         3         4
# 0  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 1  0.390528  0.166905  0.184502  0.807706  0.072960
# 2  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 3  0.484752 -0.116773  1.901755  0.238127  1.996652
# 4 -0.993263  0.196800 -1.136645  0.000366  1.025984
# 5 -0.156598 -0.031579  0.649826  2.154846 -0.610259
# 6 -0.755325 -0.346419  0.147027 -0.479448  0.558769
# 7  1.024810 -0.925874  1.862864 -1.133817  0.610478

# %%
gigga.tail(8)
# Out:
#            0         1         2         3         4
# 61  0.060971 -1.542393 -0.821110 -1.599171 -2.068836
# 62  1.509747  0.174683  0.463428 -2.206442  0.544159
# 63  0.698296  1.252944 -1.048347 -1.281320  1.276731
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314
sort_index(axis=0, ascending=False)
# Out:
#            0         1         2         3         4
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# ..       ...       ...       ...       ...       ...
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 1   0.390528  0.166905  0.184502  0.807706  0.072960
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841
#
# [69 rows x 5 columns]

# %%
gigga.to_csv("gigga.csv")

# %%
gigga.to_excel("gigga.xlsx")

# %%
nigga = gigga.copy()

# %%
nigga
# Out:
#            0         1         2         3         4
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 1   0.390528  0.166905  0.184502  0.807706  0.072960
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984
# ..       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794
#
# [69 rows x 5 columns]

# %%
nigga.tail(8)
# Out:
#            0         1           2         3         4
# 61  0.060971 -1.542393    -0.82111 -1.599171 -2.068836
# 62  1.509747  0.174683    0.463428 -2.206442  0.544159
# 63  0.698296  1.252944  himeshsexy -1.281320  1.276731
# 64  0.645132 -0.297637    0.755742  1.758122  0.307046
# 65  0.529927  0.940120    0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314142     2.60124 -0.612552 -1.714963
# 67  1.350046  1.798990   -1.312854  0.033590 -0.220208
# 68 -0.308472 -0.842066   -0.831162 -0.493941  0.552794

# %%
nigga.iloc[63,2]
# Out:
# 'himeshsexy'

# %%
nigga.loc[(nigga[0]>0.4)]
# Out:
#            0         1           2         3         4
# 2   0.638787  0.329646   -0.497104 -0.754070 -0.943406
# 3   0.484752 -0.116773    1.901755  0.238127  1.996652
# 7   1.024810 -0.925874    1.862864 -1.133817  0.610478
# 9   1.035125 -0.031160    1.939932 -1.005187 -0.741790
# 15  1.028293 -1.972605   -0.866885  0.720788 -1.223082
# 16  1.606780 -1.115710   -1.385379 -1.329660  0.041460
# 18  0.649148  0.358941   -1.080471  0.902398  0.161781
# 19  0.833029  0.975720   -0.388239  0.783316 -0.708954
# 20  0.586847 -1.621348    0.677535  0.026105 -1.678284
# 22  0.729024 -0.863091    0.305632  0.243178  0.864165
# 35  0.688408  0.081523   -0.415191  0.053661 -2.115113
# 39  0.412580  0.988773    0.513833 -0.928205  0.846904
# 45  0.942045 -0.975349   -1.054851  2.165421 -1.267240
# 47  1.359712  0.771970    0.294217 -1.391519  0.147486
# 49  1.031916 -1.081118   -0.000355 -0.219882  0.292795
# 50  0.834355 -0.140432    0.119145  0.665715  0.407586
# ...

# %%
data = {'a':1, 'b':2}

# %%
pd.DataFrame(data,[1])
# Out:
#    a  b
# 1  1  2

# %%
nigga.isnull()
# Out:
#         0      1      2      3      4
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 64  False  False  False  False  False
# 65  False  False  False  False  False
# 66  False  False  False  False  False
# 67  False  False  False  False  False
# 68  False  False  False  False  False
#
# [69 rows x 5 columns]

# %%
nigga.dropna()
# Out:
#            0         1         2         3         4
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 1   0.390528  0.166905  0.184502  0.807706  0.072960
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984
# ..       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794
#
# [69 rows x 5 columns]

# %%
nigga.fillna(value='12.3412')
# Out:
#            0         1         2         3         4
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 1   0.390528  0.166905  0.184502  0.807706  0.072960
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984
# ..       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794
#
# [69 rows x 5 columns]

# %%
dataset = {
    'Dogs':['labra','german','chihuahua','beagle','bulldog'],
    'cats':['persian','street','abc','savsd','dgfsd'],
    'price':[1232,123,2432,43534,34534]
}

# %%
df4 = pd.DataFrame(dataset)

# %%
df4
# Out:
#         Dogs     cats  price
# 0      labra  persian   1232
# 1     german   street    123
# 2  chihuahua      abc   2432
# 3     beagle    savsd  43534
# 4    bulldog    dgfsd  34534

# %%
cat = df4.groupby('Dogs')

# %%
cat
cat.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
# groupby wont work work with string anymore, it can group by features with numeric data only

# %%
pd.concat([gigga,nigga],axis=1)
# Out:
#            0         1         2         3         4         0         1  \
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841  0.302665  1.693723
# 1   0.390528  0.166905  0.184502  0.807706  0.072960  0.390528  0.166905
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406  0.638787  0.329646
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652  0.484752 -0.116773
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.993263  0.196800
# ..       ...       ...       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046  0.645132 -0.297637
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529  0.529927  0.940120
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963 -1.883809 -1.314142
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208  1.350046  1.798990
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.308472 -0.842066
#
#            2         3         4
# 0  -1.706086 -1.159119 -0.134841
# ...

# %%
pd.merge(gigga,nigga,on=3)
# Out:
#          0_x       1_x       2_x         3       4_x       0_y       1_y  \
# 0   0.302665  1.693723 -1.706086 -1.159119 -0.134841  0.302665  1.693723
# 1   0.390528  0.166905  0.184502  0.807706  0.072960  0.390528  0.166905
# 2   0.638787  0.329646 -0.497104 -0.754070 -0.943406  0.638787  0.329646
# 3   0.484752 -0.116773  1.901755  0.238127  1.996652  0.484752 -0.116773
# 4  -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.993263  0.196800
# ..       ...       ...       ...       ...       ...       ...       ...
# 64  0.645132 -0.297637  0.755742  1.758122  0.307046  0.645132 -0.297637
# 65  0.529927  0.940120  0.746221 -0.141266  0.085529  0.529927  0.940120
# 66 -1.883809 -1.314142   2.60124 -0.612552 -1.714963 -1.883809 -1.314142
# 67  1.350046  1.798990 -1.312854  0.033590 -0.220208  1.350046  1.798990
# 68 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.308472 -0.842066
#
#          2_y       4_y
# 0  -1.706086 -0.134841
# 1   0.184502  0.072960
# ...

# %%
nigga[3].nunique()
# Out:
# 69

# %%
nigga[3].value_counts()
# Out:
# 3
# -1.159119    1
#  0.929658    1
#  0.665715    1
# -0.219882    1
#  2.090539    1
#             ..
#  0.178009    1
#  0.897796    1
#  2.029544    1
# -1.667537    1
# -0.493941    1
# Name: count, Length: 69, dtype: int64

# %%
def multiply(x):
  return x*2

# %%
nigga[3].apply(multiply)
# Out:
# 0    -2.318239
# 1     1.615412
# 2    -1.508139
# 3     0.476254
# 4     0.000733
#         ...
# 64    3.516243
# 65   -0.282532
# 66   -1.225104
# 67    0.067181
# 68   -0.987883
# Name: 3, Length: 69, dtype: float64

# %%
nigga[3].apply(lambda x:x*2)
# Out:
# 0    -2.318239
# 1     1.615412
# 2    -1.508139
# 3     0.476254
# 4     0.000733
#         ...
# 64    3.516243
# 65   -0.282532
# 66   -1.225104
# 67    0.067181
# 68   -0.987883
# Name: 3, Length: 69, dtype: float64
